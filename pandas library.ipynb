# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\91887\Desktop\supermarket.xls")

# %%
df
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 0    101-17-6199      A       Cairo    Normal    Male     3       45.79
# 1    101-81-4070      C  Alexandria    Member  Female     4       62.82
# 2    102-06-2002      C  Alexandria    Member    Male     6       25.25
# 3    102-77-2261      C  Alexandria    Member    Male     4       65.31
# 4    105-10-6182      A       Cairo    Member    Male     2       21.48
# ..           ...    ...         ...       ...     ...   ...         ...
# 995  894-41-5205      C  Alexandria    Normal  Female     3       43.18
# 996  895-03-6665      B    Ismailia    Normal  Female     2       36.51
# 997  895-66-0685      B    Ismailia    Member    Male     3       18.08
# 998  896-34-0956      A       Cairo    Normal    Male     2       21.32
# 999  898-04-2717      A       Cairo    Normal    Male     2       76.40
#
#      quantity       date      time      payment    cost  gross income  rating
# ...

# %%
df.head()
# Out:
#      invoiceID branch        city cust_type  gender  type  unit_price  \
# 0  101-17-6199      A       Cairo    Normal    Male     3       45.79
# 1  101-81-4070      C  Alexandria    Member  Female     4       62.82
# 2  102-06-2002      C  Alexandria    Member    Male     6       25.25
# 3  102-77-2261      C  Alexandria    Member    Male     4       65.31
# 4  105-10-6182      A       Cairo    Member    Male     2       21.48
#
#    quantity       date      time      payment    cost  gross income  rating
# 0         7 2019-03-13  19:44:00  Credit card  320.53       16.0265     NaN
# 1         2 2019-01-17  12:36:00      eWallet  125.64        6.2820     4.9
# 2         5 2019-03-20  17:52:00         Cash  126.25        6.3125     6.1
# 3         7 2019-03-05  18:02:00  Credit card  457.17       22.8585     4.2
# 4         2 2019-02-27  12:22:00      eWallet   42.96        2.1480     6.6

# %%
df.tail()
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 995  894-41-5205      C  Alexandria    Normal  Female     3       43.18
# 996  895-03-6665      B    Ismailia    Normal  Female     2       36.51
# 997  895-66-0685      B    Ismailia    Member    Male     3       18.08
# 998  896-34-0956      A       Cairo    Normal    Male     2       21.32
# 999  898-04-2717      A       Cairo    Normal    Male     2       76.40
#
#      quantity       date      time      payment    cost  gross income  rating
# 995         8 2019-01-19  19:39:00  Credit card  345.44       17.2720     8.3
# 996         9 2019-02-16  10:52:00         Cash  328.59       16.4295     4.2
# 997         3 2019-03-05  19:46:00      eWallet   54.24        2.7120     8.0
# 998         1 2019-01-26  12:43:00         Cash   21.32        1.0660     5.9
# 999         9 2019-03-19  15:49:00      eWallet  687.60       34.3800     7.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
# invoiceID       1000 non-null object
# branch          1000 non-null object
# city            1000 non-null object
# cust_type       1000 non-null object
# gender          1000 non-null object
# type            1000 non-null int64
# unit_price      1000 non-null float64
# quantity        1000 non-null int64
# date            1000 non-null datetime64[ns]
# time            1000 non-null object
# payment         1000 non-null object
# cost            1000 non-null float64
# gross income    1000 non-null float64
# rating          998 non-null float64
# dtypes: datetime64[ns](1), float64(4), int64(2), object(7)
# memory usage: 109.5+ KB

# %%
df.describe()
# Out:
#               type   unit_price     quantity        cost  gross income  \
# count  1000.000000  1000.000000  1000.000000  1000.00000   1000.000000
# mean      3.452000    55.672130     5.510000   307.58738     15.379369
# std       1.715412    26.494628     2.923431   234.17651     11.708825
# min       1.000000    10.080000     1.000000    10.17000      0.508500
# 25%       2.000000    32.875000     3.000000   118.49750      5.924875
# 50%       3.000000    55.230000     5.000000   241.76000     12.088000
# 75%       5.000000    77.935000     8.000000   448.90500     22.445250
# max       6.000000    99.960000    10.000000   993.00000     49.650000
#
#            rating
# count  998.000000
# mean     6.971643
# std      1.719995
# min      4.000000
# 25%      5.500000
# 50%      6.950000
# 75%      8.500000
# max     10.000000

# %%
df.iloc[13,5]
# Out:
# 2

# %%
df.iloc[:5,:14] #selection through location
# Out:
#      invoiceID branch        city cust_type  gender  type  unit_price  \
# 0  101-17-6199      A       Cairo    Normal    Male     3       45.79
# 1  101-81-4070      C  Alexandria    Member  Female     4       62.82
# 2  102-06-2002      C  Alexandria    Member    Male     6       25.25
# 3  102-77-2261      C  Alexandria    Member    Male     4       65.31
# 4  105-10-6182      A       Cairo    Member    Male     2       21.48
#
#    quantity       date      time      payment    cost  gross income  rating
# 0         7 2019-03-13  19:44:00  Credit card  320.53       16.0265     NaN
# 1         2 2019-01-17  12:36:00      eWallet  125.64        6.2820     4.9
# 2         5 2019-03-20  17:52:00         Cash  126.25        6.3125     6.1
# 3         7 2019-03-05  18:02:00  Credit card  457.17       22.8585     4.2
# 4         2 2019-02-27  12:22:00      eWallet   42.96        2.1480     6.6

# %%
df['rating'].mean()
# Out:
# 6.9716432865731415

# %%
df['type'].mode()
# Out:
# 0    2
# dtype: int64

# %%
df.mean()
# Out:
# type              3.452000
# unit_price       55.672130
# quantity          5.510000
# cost            307.587380
# gross income     15.379369
# rating            6.971643
# dtype: float64

# %%
df.rename(columns={'invoiceID':'InvoiceId','branch':'Branch','city':'City','cust_type':'Customer_type'})
# Out:
#        InvoiceId Branch        City Customer_type  gender  type  unit_price  \
# 0    101-17-6199      A       Cairo        Normal    Male     3       45.79
# 1    101-81-4070      C  Alexandria        Member  Female     4       62.82
# 2    102-06-2002      C  Alexandria        Member    Male     6       25.25
# 3    102-77-2261      C  Alexandria        Member    Male     4       65.31
# 4    105-10-6182      A       Cairo        Member    Male     2       21.48
# ..           ...    ...         ...           ...     ...   ...         ...
# 995  894-41-5205      C  Alexandria        Normal  Female     3       43.18
# 996  895-03-6665      B    Ismailia        Normal  Female     2       36.51
# 997  895-66-0685      B    Ismailia        Member    Male     3       18.08
# 998  896-34-0956      A       Cairo        Normal    Male     2       21.32
# 999  898-04-2717      A       Cairo        Normal    Male     2       76.40
#
# ...

# %%
df.isnull()
# Out:
#      invoiceID  branch   city  cust_type  gender   type  unit_price  quantity  \
# 0        False   False  False      False   False  False       False     False
# 1        False   False  False      False   False  False       False     False
# 2        False   False  False      False   False  False       False     False
# 3        False   False  False      False   False  False       False     False
# 4        False   False  False      False   False  False       False     False
# ..         ...     ...    ...        ...     ...    ...         ...       ...
# 995      False   False  False      False   False  False       False     False
# 996      False   False  False      False   False  False       False     False
# 997      False   False  False      False   False  False       False     False
# 998      False   False  False      False   False  False       False     False
# 999      False   False  False      False   False  False       False     False
#
# ...

# %%
df.drop('gender',axis=1)
# Out:
#        invoiceID branch        city cust_type  type  unit_price  quantity  \
# 0    101-17-6199      A       Cairo    Normal     3       45.79         7
# 1    101-81-4070      C  Alexandria    Member     4       62.82         2
# 2    102-06-2002      C  Alexandria    Member     6       25.25         5
# 3    102-77-2261      C  Alexandria    Member     4       65.31         7
# 4    105-10-6182      A       Cairo    Member     2       21.48         2
# ..           ...    ...         ...       ...   ...         ...       ...
# 995  894-41-5205      C  Alexandria    Normal     3       43.18         8
# 996  895-03-6665      B    Ismailia    Normal     2       36.51         9
# 997  895-66-0685      B    Ismailia    Member     3       18.08         3
# 998  896-34-0956      A       Cairo    Normal     2       21.32         1
# 999  898-04-2717      A       Cairo    Normal     2       76.40         9
#
#           date      time      payment    cost  gross income  rating
# ...

# %%
df['rating'].fillna(df.rating.mean(), inplace=True)

# %%
df['type'].fillna(df.type.mode(), inplace=True)

# %%
df
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 0    101-17-6199      A       Cairo    Normal    Male     3       45.79
# 1    101-81-4070      C  Alexandria    Member  Female     4       62.82
# 2    102-06-2002      C  Alexandria    Member    Male     6       25.25
# 3    102-77-2261      C  Alexandria    Member    Male     4       65.31
# 4    105-10-6182      A       Cairo    Member    Male     2       21.48
# ..           ...    ...         ...       ...     ...   ...         ...
# 995  894-41-5205      C  Alexandria    Normal  Female     3       43.18
# 996  895-03-6665      B    Ismailia    Normal  Female     2       36.51
# 997  895-66-0685      B    Ismailia    Member    Male     3       18.08
# 998  896-34-0956      A       Cairo    Normal    Male     2       21.32
# 999  898-04-2717      A       Cairo    Normal    Male     2       76.40
#
#      quantity       date      time      payment    cost  gross income  \
# ...

# %%
df.sort_values(by='unit_price')
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 288  333-23-2632      A       Cairo    Member    Male     4       10.08
# 167  239-48-4278      A       Cairo    Member    Male     3       10.13
# 505  516-77-6464      C  Alexandria    Member  Female     4       10.16
# 850  784-21-9238      C  Alexandria    Member    Male     6       10.17
# 12   115-38-7388      C  Alexandria    Member  Female     2       10.18
# ..           ...    ...         ...       ...     ...   ...         ...
# 705  667-92-0055      A       Cairo    Member    Male     4       99.83
# 418  437-53-3084      B    Ismailia    Normal    Male     2       99.89
# 671  641-62-7288      B    Ismailia    Normal    Male     5       99.92
# 49   148-41-7930      C  Alexandria    Normal    Male     4       99.96
# 134  219-22-9386      B    Ismailia    Member    Male     6       99.96
#
#      quantity       date      time      payment    cost  gross income  rating
# ...

# %%
df.groupby(by='gender')

# %%
df[(df.payment=='Cash') & (df.branch=='A')]
# Out:
#        invoiceID branch   city cust_type  gender  type  unit_price  quantity  \
# 6    106-35-6779      A  Cairo    Member    Male     5       44.34         2
# 20   124-31-1458      A  Cairo    Member  Female     1       79.59         3
# 21   125-45-2293      A  Cairo    Normal  Female     2       99.10         6
# 28   131-70-8179      A  Cairo    Member  Female     4       92.09         3
# 29   132-23-6451      A  Cairo    Member    Male     4       20.97         5
# ..           ...    ...    ...       ...     ...   ...         ...       ...
# 955  865-41-9075      A  Cairo    Normal    Male     3       11.53         7
# 965  870-54-3162      A  Cairo    Normal  Female     6       32.25         5
# 975  877-22-3308      A  Cairo    Member    Male     4       15.87        10
# 987  886-54-6089      A  Cairo    Normal  Female     5       11.43         6
# 998  896-34-0956      A  Cairo    Normal    Male     2       21.32         1
#
# ...

# %%
df[(df.payment=='Cash') & (df.branch=='B')]
# Out:
#        invoiceID branch      city cust_type  gender  type  unit_price  \
# 10   110-48-7033      B  Ismailia    Member    Male     2       32.62
# 11   114-35-5271      B  Ismailia    Normal  Female     1       57.91
# 30   132-32-9879      B  Ismailia    Member  Female     1       93.96
# 35   135-13-8269      B  Ismailia    Member  Female     3       78.88
# 47   145-94-9061      B  Ismailia    Normal  Female     3       88.36
# ..           ...    ...       ...       ...     ...   ...         ...
# 972  873-95-4984      B  Ismailia    Member  Female     4       76.90
# 973  875-31-8302      B  Ismailia    Normal    Male     6       93.38
# 992  891-01-7034      B  Ismailia    Normal  Female     1       74.71
# 993  891-58-8335      B  Ismailia    Member  Female     6       29.61
# 996  895-03-6665      B  Ismailia    Normal  Female     2       36.51
#
#      quantity       date      time payment    cost  gross income  rating
# ...

# %%
df[(df.payment=='Cash') & (df.branch=='C')]
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 2    102-06-2002      C  Alexandria    Member    Male     6       25.25
# 14   118-62-1812      C  Alexandria    Member  Female     5       78.38
# 15   120-06-4233      C  Alexandria    Normal    Male     1       30.61
# 17   122-61-9553      C  Alexandria    Normal  Female     1       51.32
# 26   130-98-8941      C  Alexandria    Normal    Male     2       64.26
# ..           ...    ...         ...       ...     ...   ...         ...
# 950  861-77-0145      C  Alexandria    Member    Male     1       81.97
# 953  862-59-8517      C  Alexandria    Normal  Female     3       90.24
# 960  867-47-1948      C  Alexandria    Normal  Female     5       15.80
# 968  871-39-9221      C  Alexandria    Normal  Female     1       12.45
# 985  885-56-0389      C  Alexandria    Member    Male     2       52.35
#
#      quantity       date      time payment    cost  gross income  rating
# ...

# %%
df[(df.payment=='Credit card') & (df.branch=='A')]
# Out:
#        invoiceID branch   city cust_type  gender  type  unit_price  quantity  \
# 0    101-17-6199      A  Cairo    Normal    Male     3       45.79         7
# 5    105-31-1824      A  Cairo    Member    Male     6       69.52         7
# 22   126-54-1082      A  Cairo    Member  Female     5       21.54         9
# 23   127-47-6963      A  Cairo    Normal    Male     4       51.71         4
# 37   136-08-6195      A  Cairo    Normal  Female     5       69.96         8
# ..           ...    ...    ...       ...     ...   ...         ...       ...
# 961  868-06-0466      A  Cairo    Member    Male     1       69.58         9
# 967  870-76-1733      A  Cairo    Member  Female     3       14.23         5
# 970  873-14-6353      A  Cairo    Member    Male     3       24.82         7
# 980  882-40-4577      A  Cairo    Member    Male     6       67.26         4
# 986  886-18-2897      A  Cairo    Normal  Female     3       56.56         5
#
# ...

# %%
df[(df.payment=='Credit card') & (df.branch=='B')]
# Out:
#        invoiceID branch      city cust_type  gender  type  unit_price  \
# 8    109-86-4363      B  Ismailia    Member  Female     6       60.08
# 13   115-99-4379      B  Ismailia    Member  Female     2       54.73
# 16   120-54-2248      B  Ismailia    Normal  Female     3       28.86
# 32   133-77-3154      B  Ismailia    Member    Male     2       60.18
# 41   139-20-0155      B  Ismailia    Member    Male     1       40.30
# ..           ...    ...       ...       ...     ...   ...         ...
# 951  862-17-9201      B  Ismailia    Normal  Female     3       84.05
# 964  869-11-3082      B  Ismailia    Member    Male     4       96.16
# 969  871-79-8483      B  Ismailia    Normal    Male     2       94.13
# 982  883-69-1285      B  Ismailia    Member    Male     2       49.92
# 991  889-04-9723      B  Ismailia    Member  Female     3       89.14
#
#      quantity       date      time      payment    cost  gross income  \
# ...

# %%
df[(df.payment=='Credit card') & (df.branch=='C')]
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 3    102-77-2261      C  Alexandria    Member    Male     4       65.31
# 9    110-05-6330      C  Alexandria    Normal  Female     3       39.43
# 12   115-38-7388      C  Alexandria    Member  Female     2       10.18
# 27   131-15-8856      C  Alexandria    Member  Female     3       72.52
# 43   139-52-2867      C  Alexandria    Normal  Female     2       22.51
# ..           ...    ...         ...       ...     ...   ...         ...
# 976  878-30-2331      C  Alexandria    Member  Female     6       54.55
# 979  881-41-7302      C  Alexandria    Normal  Female     2       64.99
# 981  883-17-4236      C  Alexandria    Normal  Female     6       14.39
# 989  887-42-0517      C  Alexandria    Normal  Female     6       83.14
# 995  894-41-5205      C  Alexandria    Normal  Female     3       43.18
#
#      quantity       date      time      payment    cost  gross income  rating
# ...

# %%
df[(df.payment=='eWallet') & (df.branch=='A')]
# Out:
#        invoiceID branch   city cust_type  gender  type  unit_price  quantity  \
# 4    105-10-6182      A  Cairo    Member    Male     2       21.48         2
# 18   123-19-1176      A  Cairo    Member    Male     4       58.22         8
# 24   129-29-8530      A  Cairo    Member    Male     6       62.62         5
# 25   130-67-4723      A  Cairo    Member    Male     3       48.50         6
# 36   135-84-8019      A  Cairo    Normal  Female     2       77.93         9
# ..           ...    ...    ...       ...     ...   ...         ...       ...
# 983  884-80-6021      A  Cairo    Member  Female     1       73.47        10
# 984  885-17-6250      A  Cairo    Normal  Female     4       79.74         1
# 990  888-02-0338      A  Cairo    Normal    Male     1       26.23         9
# 994  892-05-6689      A  Cairo    Normal  Female     5       28.32         5
# 999  898-04-2717      A  Cairo    Normal    Male     2       76.40         9
#
# ...

# %%
df[(df.payment=='eWallet') & (df.branch=='B')]
# Out:
#        invoiceID branch      city cust_type  gender  type  unit_price  \
# 7    109-28-2512      B  Ismailia    Member  Female     2       97.61
# 33   134-54-4720      B  Ismailia    Normal  Female     1       42.42
# 44   142-63-6033      B  Ismailia    Normal    Male     5       92.36
# 52   149-15-7606      B  Ismailia    Member    Male     6       37.32
# 63   154-74-7179      B  Ismailia    Normal    Male     6       54.45
# ..           ...    ...       ...       ...     ...   ...         ...
# 930  848-07-1692      B  Ismailia    Normal  Female     4       57.22
# 945  857-67-9057      B  Ismailia    Normal    Male     1       22.95
# 958  866-70-2814      B  Ismailia    Normal  Female     1       52.79
# 974  875-46-5808      B  Ismailia    Member    Male     4       25.90
# 997  895-66-0685      B  Ismailia    Member    Male     3       18.08
#
#      quantity       date      time  payment    cost  gross income  rating
# ...

# %%
df[(df.payment=='eWallet') & (df.branch=='C')]
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 1    101-81-4070      C  Alexandria    Member  Female     4       62.82
# 19   123-35-4896      C  Alexandria    Normal  Female     6       46.66
# 38   137-63-5492      C  Alexandria    Normal    Male     1       58.76
# 39   137-74-8729      C  Alexandria    Normal  Female     2       12.19
# 57   151-27-8496      C  Alexandria    Normal  Female     1       56.13
# ..           ...    ...         ...       ...     ...   ...         ...
# 913  835-16-0096      C  Alexandria    Member    Male     6       14.70
# 917  838-78-4295      C  Alexandria    Normal  Female     4       33.47
# 918  840-19-2096      C  Alexandria    Member    Male     1       87.91
# 934  848-95-6252      C  Alexandria    Member  Female     5       86.27
# 988  886-77-9084      C  Alexandria    Normal    Male     1       71.89
#
#      quantity       date      time  payment    cost  gross income  rating
# ...

# %%
df.to_excel('Bigbazaar.xlsx',index=True)

# %%
df
# Out:
#        invoiceID branch        city cust_type  gender  type  unit_price  \
# 0    101-17-6199      A       Cairo    Normal    Male     3       45.79
# 1    101-81-4070      C  Alexandria    Member  Female     4       62.82
# 2    102-06-2002      C  Alexandria    Member    Male     6       25.25
# 3    102-77-2261      C  Alexandria    Member    Male     4       65.31
# 4    105-10-6182      A       Cairo    Member    Male     2       21.48
# ..           ...    ...         ...       ...     ...   ...         ...
# 995  894-41-5205      C  Alexandria    Normal  Female     3       43.18
# 996  895-03-6665      B    Ismailia    Normal  Female     2       36.51
# 997  895-66-0685      B    Ismailia    Member    Male     3       18.08
# 998  896-34-0956      A       Cairo    Normal    Male     2       21.32
# 999  898-04-2717      A       Cairo    Normal    Male     2       76.40
#
#      quantity       date      time      payment    cost  gross income  \
# ...
